# %% [markdown]
# # Introduction
# See https://github.com/wtsi-team112/fits/issues/4
#
# Magnus sent a file with the following files that are in FITS but not in the Pf 6.2 manifest:
# ```
# sample	study_name	irods_path	sanger_sample_id
# NULL	Plasmodium falciparum genome variation 1	/seq/6901/6901_8_nonhuman#2.bam	Tr5E
# NULL	Plasmodium falciparum genome variation 1	/seq/6901/6901_8_nonhuman#11.bam	Tr3E
# NULL	Plasmodium falciparum genome variation 1	/seq/6901/6901_8_nonhuman#10.bam	Tr5E_1
# NULL	Plasmodium falciparum genome variation 1	/seq/6901/6901_8_nonhuman#3.bam	Tr3E_1
# PD0338-C	Test sequencing of high level human contamination.	/seq/12135/12135_6#66.cram	2876STDY5684799
# QE0008-C	Test sequencing of high level human contamination.	/seq/12135/12135_7#68.cram	2876STDY5684801
# QE0022-C	Test sequencing of high level human contamination.	/seq/12135/12135_7#70.cram	2876STDY5684803
# QE0145-C	Test sequencing of high level human contamination.	/seq/12135/12135_7#69.cram	2876STDY5684802
# QE0196-C	Test sequencing of high level human contamination.	/seq/12135/12135_7#67.cram	2876STDY5684800
# QE0212-C	Test sequencing of high level human contamination.	/seq/12135/12135_7#71.cram	2876STDY5684804
# ```
# I couldn't see an obvious explanation as to why these weren't in Pf 6.2. Here I investigate these.

# %%
# %run ../setup.ipynb
# Out:
# <style type="text/css">
# .container {
#     width: 100%;
# }
# # div#notebook {
# #     padding-top: 1em;
# # }
# # #header-container {
# #     display: none;
# # }
# # #header-bar {
# #     display: none;
# # }
# # #maintoolbar {
# #     display: none;
# # }
# # #menubar-container {
# #     position: fixed;
# #     margin-top: 0;
# # }
# site {
#     height: auto !important;
# }
# </style>
# python 3.5.2 |Continuum Analytics, Inc.| (default, Jul  2 2016, 17:53:06)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# numpy 1.13.3
# scipy 0.19.1
# pandas 0.22.0
# numexpr 2.6.4
# pysam 0.8.4
# pysamstats 0.24.3
# petlx 1.0.3
# vcf 0.6.8
# h5py 2.7.0
# tables 3.4.2
# zarr 2.2.0
# scikit-allel 1.1.10

# %%
# Inputs
mlwh_missing_exceptions_fn = '/nfs/team112_internal/rp7/src/github/wtsi-team112/SIMS/meta/mlwh/mlwh_missing_exceptions.txt'
mlwh_study_exceptions_fn = '/nfs/team112_internal/rp7/src/github/wtsi-team112/SIMS/meta/mlwh/mlwh_study_exceptions.txt'
mlwh_sample_exceptions_fn = '/nfs/team112_internal/rp7/src/github/wtsi-team112/SIMS/meta/mlwh/mlwh_sample_exceptions.txt'
mlwh_taxon_exceptions_fn = '/nfs/team112_internal/rp7/src/github/wtsi-team112/SIMS/meta/mlwh/mlwh_taxon_exceptions.txt'
sequencescape_alfresco_study_mappings_fn='/nfs/team112_internal/rp7/src/github/wtsi-team112/SIMS/meta/mlwh/sequencescape_alfresco_study_mappings.txt'

# Outputs
output_fn = 'Pf_62_Pv4_like_manifest_20180906.txt'
manifest_symlink = 'pf_62_manifest.txt'
input_dir = '/lustre/scratch118/malaria/team112/pipelines/setups/pf_62/input'

# %% [markdown]
# # Does the mlwh query pull in these files?

# %%
def set_irods_name(row):
    # First calculate prefix using nonhuman dependent on id_run and species (taxon)
    # Then calculate tag string (empty string if no tag)
    # Then calculate file extension
    # Then concat these three strings
    if (
        (row['taxon_id'] in [7165, 7173, 30066, 62324]) & # Anopheles gambiae, arabiensis, merus and funestus respectively
        (row['id_run'] <= 6750)
    ):
        prefix = "%d_%d_nonhuman" % (row['id_run'], row['position'])
    elif (
        ~(row['taxon_id'] in [7165, 7173, 30066, 62324]) & # Anopheles gambiae, arabiensis, merus and funestus respectively
        (row['id_run'] <= 7100)
    ):
        prefix = "%d_%d_nonhuman" % (row['id_run'], row['position'])
    else:
        prefix = "%d_%d" % (row['id_run'], row['position'])
        
    if np.isnan(row['tag_index']):
        tag_string = ''
    else:
        tag_string = '#%d' % row['tag_index']
    
    if row['id_run'] <= 10300:
        file_extension = '.bam'
    else:
        file_extension = '.cram'
    
    irods_filename = prefix + tag_string + file_extension
    return(irods_filename)

def set_sample_id(row):
    if row['sample'] is None:
        return('DS_%s' % row['name'])
    else:
        return('DS_%s' % row['sample'])

def is_valid_alfresco_code(s):
    try: 
        int(s[0:4])
        return True
    except ValueError:
        return False

def create_build_manifest(
#     taxon_ids=[5833, 5855, 5858, 5821, 7165, 7173, 30066], # Pf, Pv, Pm, Pb, Ag, A. arabiensis, A. merus
    taxon_ids=[5833, 36329, 5847, 57267, 137071], # Pf, 3D7, V1, Dd2, HB3
    # 1089 is excluded as this is R&D samples. 1204 and 1176 are excluded as these are CP1 samples. 1175 is excluded as some Pf R&D samples were incorrectly tagged with this study
    studies_to_exclude = ['1089-R&amp;D-GB-ALCOCK', '1204-PF-GM-CP1', '1176-PF-KE-CP1', '1175-VO-KH-STLAURENT'],
    miseq_runs_to_allow = [13809, 13810], # Two Miseq runs within 24 samples on each from study 1095-PF-TZ-ISHENGOMA that were included in Pf 6.0
    input_dir = input_dir,
    mlwh_missing_exceptions_fn = mlwh_missing_exceptions_fn,
    mlwh_study_exceptions_fn = mlwh_study_exceptions_fn,
    mlwh_sample_exceptions_fn = mlwh_sample_exceptions_fn,
    mlwh_taxon_exceptions_fn = mlwh_taxon_exceptions_fn,
    sequencescape_alfresco_study_mappings_fn = sequencescape_alfresco_study_mappings_fn,
    output_columns = [
        'path',
        'study',
        'sample',
        'lane',
        'reads',
        'paired',
        'irods_path',
        'sanger_sample_id',
        'taxon_id',
        'study_lims',
        'study_name',
        'id_run',
        'position',
        'tag_index',
        'qc_complete',
        'manual_qc',
        'description',
        'instrument_name',
        'instrument_model',
        'forward_read_length',
        'requested_insert_size_from',
        'requested_insert_size_to',
        'human_percent_mapped',
        'subtrack_filename',
        'subtrack_files_bytes',
        'ebi_run_acc'
    ]
):
    """Create a DataFrame to be used as a build manifest.
    
    A build manifest here is a list of all the "lanelets" that need to be
    included in a build. The output will typically be written to a
    tab-delmited file, either to use as input to vr-pipe, or perhaps as
    input to a vr-track DB.

    Args:
        taxon_ids (list of int): The taxons of the build (P. falciparum is '5833',
            P. vivax is '5855').
        sequencescape_alfresco_study_mappings_fn (str): filename of
            mappings from sequencscape to alfresco study mappings

    Returns:
        pd.DataFrame: The build manifest.

    """
    
    # Read in taxon exceptions file
    df_mlwh_taxon_exceptions = pd.read_csv(mlwh_taxon_exceptions_fn, sep='\t', dtype={'tag_index': str, 'taxon_id': int}, index_col='irods_filename')
    df_mlwh_taxon_exceptions['tag_index'].fillna('', inplace=True)
    # Identify which samples in exceptions file match the taxon of current build, and which don't
    df_mlwh_exceptions_this_taxon = df_mlwh_taxon_exceptions.loc[df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids)]
    df_mlwh_exceptions_other_taxa = df_mlwh_taxon_exceptions.loc[~(df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids))]

    # Read in sample exceptions file
    df_mlwh_sample_exceptions = pd.read_csv(mlwh_sample_exceptions_fn, sep='\t', index_col='irods_filename')

    # Read in study exceptions file
    df_mlwh_study_exceptions = pd.read_csv(mlwh_study_exceptions_fn, sep='\t', index_col='irods_filename')

    # Read in missing exceptions file
    df_mlwh_missing_exceptions = pd.read_csv(mlwh_missing_exceptions_fn, sep='\t', index_col='irods_filename')
    df_mlwh_missing_exceptions['derivative_sample_id'] = 'DS_' + df_mlwh_missing_exceptions['sample_id']
    df_mlwh_missing_exceptions = df_mlwh_missing_exceptions.loc[
        df_mlwh_missing_exceptions['taxon_id'].isin(taxon_ids)
    ]

    # Read in SequenceScape-Alfresco study mappings
    df_sequencescape_alfresco_study_mappings = pd.read_csv(sequencescape_alfresco_study_mappings_fn, sep='\t', index_col='seqscape_study_id')
    sequencescape_alfresco_study_mappings_dict = df_sequencescape_alfresco_study_mappings.loc[
        :,
#         df_sequencescape_alfresco_study_mappings['build_flag']==1,
        'alfresco_study_code'
    ].to_dict()
    
    # Read in data from mlwh matching this taxon, plus samples from exceptions file matching this taxon
    conn = pymysql.connect(
        host='mlwh-db',
        user='mlwh_malaria',
        password='Solaris&2015',
        db='mlwarehouse',
        port=3435
    )
    
    sql_query = 'SELECT \
        study.name as study_name, \
        study.id_study_lims as study_lims, \
        sample.supplier_name as sample, \
        sample.name, \
        sample.sanger_sample_id, \
        sample.taxon_id, \
        iseq_product_metrics.id_run, \
        iseq_product_metrics.position, \
        iseq_product_metrics.tag_index, \
        iseq_product_metrics.num_reads, \
        iseq_product_metrics.human_percent_mapped, \
        iseq_run_lane_metrics.instrument_name, \
        iseq_run_lane_metrics.instrument_model, \
        iseq_run_lane_metrics.paired_read, \
        iseq_run_lane_metrics.qc_complete, \
        iseq_flowcell.manual_qc, \
        iseq_flowcell.requested_insert_size_from, \
        iseq_flowcell.requested_insert_size_to, \
        iseq_flowcell.forward_read_length, \
        iseq_run_status_dict.description \
    FROM \
        study, \
        iseq_flowcell, \
        sample, \
        iseq_product_metrics, \
        iseq_run_status, \
        iseq_run_lane_metrics, \
        iseq_run_status_dict \
    WHERE \
        study.id_study_tmp = iseq_flowcell.id_study_tmp and \
        iseq_flowcell.id_sample_tmp = sample.id_sample_tmp and \
        iseq_flowcell.manual_qc = 1 and \
        iseq_product_metrics.id_iseq_flowcell_tmp = iseq_flowcell.id_iseq_flowcell_tmp and \
        iseq_run_status.id_run = iseq_product_metrics.id_run and \
        iseq_product_metrics.id_run = iseq_run_lane_metrics.id_run and \
        iseq_product_metrics.position = iseq_run_lane_metrics.position and \
        iseq_run_status.iscurrent = 1 and \
        ( ( iseq_run_lane_metrics.instrument_model != "MiSeq" ) or (iseq_product_metrics.id_run in (%s)) ) and \
        iseq_run_status.id_run_status_dict = iseq_run_status_dict.id_run_status_dict and \
        study.faculty_sponsor = "Dominic Kwiatkowski" and \
        ( ( sample.taxon_id in (%s) ) or ' % (
            ', '.join([str(x) for x in miseq_runs_to_allow]),
            ', '.join([str(x) for x in taxon_ids])
        )
    sql_query = sql_query + ' or '.join(
        df_mlwh_taxon_exceptions.loc[df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids)].apply(
            lambda x: '(iseq_product_metrics.id_run="%s" and iseq_product_metrics.position="%s" and iseq_product_metrics.tag_index="%s")' % (x['id_run'], x['position'], x['tag_index']),
            1
        )
    )
    sql_query = sql_query + ')'
#         (iseq_flowcell.manual_qc = 1 or iseq_flowcell.manual_qc is null) and \
    
    df_return = pd.read_sql(sql_query, conn)

    # Replace missing taxon_id with -1 (can't have missing int values in pandas Series)
    df_return['taxon_id'] = df_return['taxon_id'].fillna(-1).astype('int32')

    # Determine file name in iRods
    df_return['irods_filename'] = df_return.apply(set_irods_name, 1)
    df_return.set_index('irods_filename', inplace=True)

    return(df_return)

# %%
df_mlwh = create_build_manifest()
df_mlwh[0:3]
# Out:
#                                                    study_name study_lims  \
# irods_filename
# 1337_1_nonhuman.bam  Plasmodium falciparum genome variation 1        578
# 1337_2_nonhuman.bam  Plasmodium falciparum genome variation 1        578
# 1337_3_nonhuman.bam  Plasmodium falciparum genome variation 1        578
#
#                     sample           name sanger_sample_id  taxon_id  id_run  \
# irods_filename
# 1337_1_nonhuman.bam   None  AK121_D80 300             None      5833    1337
# 1337_2_nonhuman.bam   None  AK121_D80 200             None      5833    1337
# 1337_3_nonhuman.bam   None  AK121_D80 200             None      5833    1337
#
#                      position  tag_index  num_reads  human_percent_mapped  \
# irods_filename
# 1337_1_nonhuman.bam         1        NaN    2745194                 60.35
# 1337_2_nonhuman.bam         2        NaN    4310986                 58.68
# 1337_3_nonhuman.bam         3        NaN   14488586                 57.19
#
#                     instrument_name instrument_model  paired_read  \
# irods_filename
# 1337_1_nonhuman.bam            IL29               HK            1
# 1337_2_nonhuman.bam            IL29               HK            1
# 1337_3_nonhuman.bam            IL29               HK            1
#
#                             qc_complete  manual_qc  \
# irods_filename
# 1337_1_nonhuman.bam 2008-09-24 15:54:04          1
# 1337_2_nonhuman.bam 2008-09-24 15:54:04          1
# 1337_3_nonhuman.bam 2008-09-24 15:54:04          1
#
#                      requested_insert_size_from  requested_insert_size_to  \
# irods_filename
# 1337_1_nonhuman.bam                       300.0                     300.0
# 1337_2_nonhuman.bam                       200.0                     200.0
# 1337_3_nonhuman.bam                       200.0                     200.0
#
#                      forward_read_length  description
# irods_filename
# 1337_1_nonhuman.bam                   37  qc complete
# 1337_2_nonhuman.bam                   37  qc complete
# 1337_3_nonhuman.bam                   37  qc complete

# %%
df_mlwh.loc[df_mlwh['id_run'] == 6901]
# Out:
#                                                       study_name study_lims  \
# irods_filename
# 6901_3_nonhuman#1.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#2.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#3.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#4.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#5.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#6.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#7.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#8.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#9.bam   Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#10.bam  Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#11.bam  Plasmodium falciparum genome variation 1        578
# 6901_3_nonhuman#12.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#13.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#14.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#15.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#16.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#17.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#18.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#19.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#20.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#21.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#22.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#23.bam  Plasmodium falciparum genome variation 1        578
# 6901_4_nonhuman#24.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#25.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#26.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#27.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#28.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#29.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#30.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#31.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#32.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#33.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#34.bam  Plasmodium falciparum genome variation 1        578
# 6901_5_nonhuman#35.bam  Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#1.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#2.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#3.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#4.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#5.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#6.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#7.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#8.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#9.bam   Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#10.bam  Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#11.bam  Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#12.bam  Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#13.bam  Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#14.bam  Plasmodium falciparum genome variation 1        578
#
#                        sample       name sanger_sample_id  taxon_id  id_run  \
# irods_filename
# 6901_3_nonhuman#1.bam    None   PF0477-C             None      5833    6901
# 6901_3_nonhuman#2.bam    None   PF0479-C             None      5833    6901
# 6901_3_nonhuman#3.bam    None   PF0473-C             None      5833    6901
# 6901_3_nonhuman#4.bam    None   PF0522-C             None      5833    6901
# 6901_3_nonhuman#5.bam    None   PF0463-C             None      5833    6901
# 6901_3_nonhuman#6.bam    None   PF0531-C             None      5833    6901
# 6901_3_nonhuman#7.bam    None   PF0512-C             None      5833    6901
# 6901_3_nonhuman#8.bam    None   PF0454-C             None      5833    6901
# 6901_3_nonhuman#9.bam    None   PF0472-C             None      5833    6901
# 6901_3_nonhuman#10.bam   None   PF0504-C             None      5833    6901
# 6901_3_nonhuman#11.bam   None   PF0464-C             None      5833    6901
# 6901_3_nonhuman#12.bam   None   PF0456-C             None      5833    6901
# 6901_4_nonhuman#13.bam   None  PZ0001-CW             None      5833    6901
# 6901_4_nonhuman#14.bam   None  PZ0002-CW             None      5833    6901
# 6901_4_nonhuman#15.bam   None  PZ0003-CW             None      5833    6901
# 6901_4_nonhuman#16.bam   None  PZ0004-CW             None      5833    6901
# 6901_4_nonhuman#17.bam   None  PZ0005-CW             None      5833    6901
# 6901_4_nonhuman#18.bam   None  PZ0006-CW             None      5833    6901
# 6901_4_nonhuman#19.bam   None   PZ0007-C             None      5833    6901
# 6901_4_nonhuman#20.bam   None  PZ0008-CW             None      5833    6901
# 6901_4_nonhuman#21.bam   None  PZ0009-CW             None      5833    6901
# 6901_4_nonhuman#22.bam   None  PZ0010-CW             None      5833    6901
# 6901_4_nonhuman#23.bam   None  PZ0011-CW             None      5833    6901
# 6901_4_nonhuman#24.bam   None   PZ0012_C             None      5833    6901
# 6901_5_nonhuman#25.bam   None  PH0493-CW             None      5833    6901
# 6901_5_nonhuman#26.bam   None  PH0494-CW             None      5833    6901
# 6901_5_nonhuman#27.bam   None  PH0495-CW             None      5833    6901
# 6901_5_nonhuman#28.bam   None  PH0496-CW             None      5833    6901
# 6901_5_nonhuman#29.bam   None  PH0497-CW             None      5833    6901
# 6901_5_nonhuman#30.bam   None  PH0498-CW             None      5833    6901
# 6901_5_nonhuman#31.bam   None  PH0499-CW             None      5833    6901
# 6901_5_nonhuman#32.bam   None  PH0500-CW             None      5833    6901
# 6901_5_nonhuman#33.bam   None  PH0501-CW             None      5833    6901
# 6901_5_nonhuman#34.bam   None  PG0120-CW             None      5833    6901
# 6901_5_nonhuman#35.bam   None   PG0121-C             None      5833    6901
# 6901_8_nonhuman#1.bam    None   PH0540-C             None      5833    6901
# 6901_8_nonhuman#2.bam    None       Tr5E             None      5833    6901
# 6901_8_nonhuman#3.bam    None     Tr3E_1             None      5833    6901
# 6901_8_nonhuman#4.bam    None   PH0545-C             None      5833    6901
# 6901_8_nonhuman#5.bam    None   PH0535-C             None      5833    6901
# 6901_8_nonhuman#6.bam    None   PH0526-C             None      5833    6901
# 6901_8_nonhuman#7.bam    None   PH0530-C             None      5833    6901
# 6901_8_nonhuman#8.bam    None   PH0532-C             None      5833    6901
# 6901_8_nonhuman#9.bam    None   PH0546-C             None      5833    6901
# 6901_8_nonhuman#10.bam   None     Tr5E_1             None      5833    6901
# 6901_8_nonhuman#11.bam   None       Tr3E             None      5833    6901
# 6901_8_nonhuman#12.bam   None   PH0529-C             None      5833    6901
# 6901_8_nonhuman#13.bam   None   PH0527-C             None      5833    6901
# 6901_8_nonhuman#14.bam   None   PH0543-C             None      5833    6901
#
#                         position  tag_index  num_reads  human_percent_mapped  \
# irods_filename
# 6901_3_nonhuman#1.bam          3        1.0   15195722                 89.33
# 6901_3_nonhuman#2.bam          3        2.0   22994194                 90.78
# 6901_3_nonhuman#3.bam          3        3.0   18145404                 80.67
# 6901_3_nonhuman#4.bam          3        4.0   22990098                 74.86
# 6901_3_nonhuman#5.bam          3        5.0   15795786                 85.70
# 6901_3_nonhuman#6.bam          3        6.0   16618420                 81.78
# 6901_3_nonhuman#7.bam          3        7.0   20197362                 87.67
# 6901_3_nonhuman#8.bam          3        8.0   19465296                 91.49
# 6901_3_nonhuman#9.bam          3        9.0   14194180                 96.48
# 6901_3_nonhuman#10.bam         3       10.0   23747352                 79.99
# 6901_3_nonhuman#11.bam         3       11.0   22377650                 74.10
# 6901_3_nonhuman#12.bam         3       12.0   18611384                 92.69
# 6901_4_nonhuman#13.bam         4       13.0   13525420                 99.37
# 6901_4_nonhuman#14.bam         4       14.0   21008120                 79.66
# 6901_4_nonhuman#15.bam         4       15.0   14580386                 92.25
# 6901_4_nonhuman#16.bam         4       16.0   25527232                 98.64
# 6901_4_nonhuman#17.bam         4       17.0   13915156                 94.43
# 6901_4_nonhuman#18.bam         4       18.0   14123162                 99.09
# 6901_4_nonhuman#19.bam         4       19.0   15825566                 99.38
# 6901_4_nonhuman#20.bam         4       20.0   12100760                 99.27
# 6901_4_nonhuman#21.bam         4       21.0   16239972                 98.70
# 6901_4_nonhuman#22.bam         4       22.0   14206554                 99.29
# 6901_4_nonhuman#23.bam         4       23.0   24807566                 96.47
# 6901_4_nonhuman#24.bam         4       24.0     974524                 99.50
# 6901_5_nonhuman#25.bam         5       25.0    2561942                 75.94
# 6901_5_nonhuman#26.bam         5       26.0   33483224                 88.06
# 6901_5_nonhuman#27.bam         5       27.0   20744206                 77.76
# 6901_5_nonhuman#28.bam         5       28.0   26696498                 75.53
# 6901_5_nonhuman#29.bam         5       29.0   18872142                 66.63
# 6901_5_nonhuman#30.bam         5       30.0   17575026                 67.07
# 6901_5_nonhuman#31.bam         5       31.0   25563546                 68.43
# 6901_5_nonhuman#32.bam         5       32.0   18842286                 72.96
# 6901_5_nonhuman#33.bam         5       33.0   25921218                 73.40
# 6901_5_nonhuman#34.bam         5       34.0   19275848                 96.78
# 6901_5_nonhuman#35.bam         5       35.0   25600178                 98.65
# 6901_8_nonhuman#1.bam          8        1.0    4969844                 99.42
# 6901_8_nonhuman#2.bam          8        2.0      52856                 93.42
# 6901_8_nonhuman#3.bam          8        3.0     353834                 98.46
# 6901_8_nonhuman#4.bam          8        4.0   13389882                 99.41
# 6901_8_nonhuman#5.bam          8        5.0    2341808                 99.48
# 6901_8_nonhuman#6.bam          8        6.0    4612274                 99.47
# 6901_8_nonhuman#7.bam          8        7.0    7985930                 99.43
# 6901_8_nonhuman#8.bam          8        8.0   14623356                 99.40
# 6901_8_nonhuman#9.bam          8        9.0    3781224                 99.44
# 6901_8_nonhuman#10.bam         8       10.0      68518                 96.61
# 6901_8_nonhuman#11.bam         8       11.0     289576                 94.41
# 6901_8_nonhuman#12.bam         8       12.0    5091710                 99.44
# 6901_8_nonhuman#13.bam         8       13.0   27655836                 99.32
# 6901_8_nonhuman#14.bam         8       14.0    3000612                 99.46
#
#                        instrument_name instrument_model  paired_read  \
# irods_filename
# 6901_3_nonhuman#1.bam             HS13            HiSeq            1
# 6901_3_nonhuman#2.bam             HS13            HiSeq            1
# 6901_3_nonhuman#3.bam             HS13            HiSeq            1
# 6901_3_nonhuman#4.bam             HS13            HiSeq            1
# 6901_3_nonhuman#5.bam             HS13            HiSeq            1
# 6901_3_nonhuman#6.bam             HS13            HiSeq            1
# 6901_3_nonhuman#7.bam             HS13            HiSeq            1
# 6901_3_nonhuman#8.bam             HS13            HiSeq            1
# 6901_3_nonhuman#9.bam             HS13            HiSeq            1
# 6901_3_nonhuman#10.bam            HS13            HiSeq            1
# 6901_3_nonhuman#11.bam            HS13            HiSeq            1
# 6901_3_nonhuman#12.bam            HS13            HiSeq            1
# 6901_4_nonhuman#13.bam            HS13            HiSeq            1
# 6901_4_nonhuman#14.bam            HS13            HiSeq            1
# 6901_4_nonhuman#15.bam            HS13            HiSeq            1
# 6901_4_nonhuman#16.bam            HS13            HiSeq            1
# 6901_4_nonhuman#17.bam            HS13            HiSeq            1
# 6901_4_nonhuman#18.bam            HS13            HiSeq            1
# 6901_4_nonhuman#19.bam            HS13            HiSeq            1
# 6901_4_nonhuman#20.bam            HS13            HiSeq            1
# 6901_4_nonhuman#21.bam            HS13            HiSeq            1
# 6901_4_nonhuman#22.bam            HS13            HiSeq            1
# 6901_4_nonhuman#23.bam            HS13            HiSeq            1
# 6901_4_nonhuman#24.bam            HS13            HiSeq            1
# 6901_5_nonhuman#25.bam            HS13            HiSeq            1
# 6901_5_nonhuman#26.bam            HS13            HiSeq            1
# 6901_5_nonhuman#27.bam            HS13            HiSeq            1
# 6901_5_nonhuman#28.bam            HS13            HiSeq            1
# 6901_5_nonhuman#29.bam            HS13            HiSeq            1
# 6901_5_nonhuman#30.bam            HS13            HiSeq            1
# 6901_5_nonhuman#31.bam            HS13            HiSeq            1
# 6901_5_nonhuman#32.bam            HS13            HiSeq            1
# 6901_5_nonhuman#33.bam            HS13            HiSeq            1
# 6901_5_nonhuman#34.bam            HS13            HiSeq            1
# 6901_5_nonhuman#35.bam            HS13            HiSeq            1
# 6901_8_nonhuman#1.bam             HS13            HiSeq            1
# 6901_8_nonhuman#2.bam             HS13            HiSeq            1
# 6901_8_nonhuman#3.bam             HS13            HiSeq            1
# 6901_8_nonhuman#4.bam             HS13            HiSeq            1
# 6901_8_nonhuman#5.bam             HS13            HiSeq            1
# 6901_8_nonhuman#6.bam             HS13            HiSeq            1
# 6901_8_nonhuman#7.bam             HS13            HiSeq            1
# 6901_8_nonhuman#8.bam             HS13            HiSeq            1
# 6901_8_nonhuman#9.bam             HS13            HiSeq            1
# 6901_8_nonhuman#10.bam            HS13            HiSeq            1
# 6901_8_nonhuman#11.bam            HS13            HiSeq            1
# 6901_8_nonhuman#12.bam            HS13            HiSeq            1
# 6901_8_nonhuman#13.bam            HS13            HiSeq            1
# 6901_8_nonhuman#14.bam            HS13            HiSeq            1
#
#                                qc_complete  manual_qc  \
# irods_filename
# 6901_3_nonhuman#1.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#2.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#3.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#4.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#5.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#6.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#7.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#8.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#9.bam  2011-11-01 12:52:25          1
# 6901_3_nonhuman#10.bam 2011-11-01 12:52:25          1
# 6901_3_nonhuman#11.bam 2011-11-01 12:52:25          1
# 6901_3_nonhuman#12.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#13.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#14.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#15.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#16.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#17.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#18.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#19.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#20.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#21.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#22.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#23.bam 2011-11-01 12:52:25          1
# 6901_4_nonhuman#24.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#25.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#26.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#27.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#28.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#29.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#30.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#31.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#32.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman#33.bam 2011-11-01 12:52:25          1
# 6901_5_nonhuman
# 6901_8_nonhuman#4.bam                        200.0                     300.0
# 6901_8_nonhuman#5.bam                        200.0                     300.0
# 6901_8_nonhuman#6.bam                        200.0                     300.0
# 6901_8_nonhuman#7.bam                        200.0                     300.0
# 6901_8_nonhuman#8.bam                        200.0                     300.0
# 6901_8_nonhuman#9.bam                        200.0                     300.0
# 6901_8_nonhuman#10.bam                       200.0                     300.0
# 6901_8_nonhuman#11.bam                       200.0                     300.0
# 6901_8_nonhuman#12.bam                       200.0                     300.0
# 6901_8_nonhuman#13.bam                       200.0                     300.0
# 6901_8_nonhuman#14.bam                       200.0                     300.0
#
#                         forward_read_length  description
# irods_filename
# 6901_3_nonhuman#1.bam                   100  qc complete
# 6901_3_nonhuman#2.bam                   100  qc complete
# 6901_3_nonhuman#3.bam                   100  qc complete
# 6901_3_nonhuman#4.bam                   100  qc complete
# 6901_3_nonhuman#5.bam                   100  qc complete
# 6901_3_nonhuman#6.bam                   100  qc complete
# 6901_3_nonhuman#7.bam                   100  qc complete
# 6901_3_nonhuman#8.bam                   100  qc complete
# 6901_3_nonhuman#9.bam                   100  qc complete
# 6901_3_nonhuman#10.bam                  100  qc complete
# 6901_3_nonhuman#11.bam                  100  qc complete
# 6901_3_nonhuman#12.bam                  100  qc complete
# 6901_4_nonhuman#13.bam                  100  qc complete
# 6901_4_nonhuman#14.bam                  100  qc complete
# 6901_4_nonhuman#15.bam                  100  qc complete
# 6901_4_nonhuman#16.bam                  100  qc complete
# 6901_4_nonhuman#17.bam                  100  qc complete
# 6901_4_nonhuman#18.bam                  100  qc complete
# 6901_4_nonhuman#19.bam                  100  qc complete
# 6901_4_nonhuman#20.bam                  100  qc complete
# 6901_4_nonhuman#21.bam                  100  qc complete
# 6901_4_nonhuman#22.bam                  100  qc complete
# 6901_4_nonhuman#23.bam                  100  qc complete
# 6901_4_nonhuman#24.bam                  100  qc complete
# 6901_5_nonhuman#25.bam                  100  qc complete
# 6901_5_nonhuman#26.bam                  100  qc complete
# 6901_5_nonhuman#27.bam                  100  qc complete
# 6901_5_nonhuman#28.bam                  100  qc complete
# 6901_5_nonhuman#29.bam                  100  qc complete
# 6901_5_nonhuman#30.bam                  100  qc complete
# 6901_5_nonhuman#31.bam                  100  qc complete
# 6901_5_nonhuman#32.bam                  100  qc complete
# 6901_5_nonhuman#33.bam                  100  qc complete
# 6901_5_nonhuman#34.bam                  100  qc complete
# 6901_5_nonhuman#35.bam                  100  qc complete
# 6901_8_nonhuman#1.bam                   100  qc complete
# 6901_8_nonhuman#2.bam                   100  qc complete
# 6901_8_nonhuman#3.bam                   100  qc complete
# 6901_8_nonhuman#4.bam                   100  qc complete
# 6901_8_nonhuman#5.bam                   100  qc complete
# 6901_8_nonhuman#6.bam                   100  qc complete
# 6901_8_nonhuman#7.bam                   100  qc complete
# 6901_8_nonhuman#8.bam                   100  qc complete
# 6901_8_nonhuman#9.bam                   100  qc complete
# 6901_8_nonhuman#10.bam                  100  qc complete
# 6901_8_nonhuman#11.bam                  100  qc complete
# 6901_8_nonhuman#12.bam                  100  qc complete
# 12135_5#59.cram   12135         5       59.0    3306334                 99.04
# 12135_5#60.cram   12135         5       60.0    7780290                 99.49
# 12135_6#61.cram   12135         6       61.0    6752670                 99.53
# 12135_6#62.cram   12135         6       62.0   14254540                 99.20
# 12135_6#63.cram   12135         6       63.0    6991004                 99.52
# 12135_6#64.cram   12135         6       64.0    6460296                 99.51
# 12135_6#65.cram   12135         6       65.0    6109270                 99.48
# 12135_6#66.cram   12135         6       66.0    4663282                 99.44
# 12135_7#67.cram   12135         7       67.0    3498108                 99.57
# 12135_7#68.cram   12135         7       68.0    6843374                 99.50
# 12135_7#69.cram   12135         7       69.0    3067626                 99.54
# 12135_7#70.cram   12135         7       70.0   16264426                 99.49
# 12135_7#71.cram   12135         7       71.0    5631900                 99.54
# 12135_8#73.cram   12135         8       73.0   32819612                 99.17
# 12135_8#74.cram   12135         8       74.0   29713518                 98.86
# 12135_8#75.cram   12135         8       75.0   51806556                 93.66
# 12135_8#76.cram   12135         8       76.0   47580480                 98.20
# 12135_8#77.cram   12135         8       77.0   50653168                 97.35
# 12135_8#78.cram   12135         8       78.0   52981598                 96.60
# 12135_8#79.cram   12135         8       79.0   48504104                 97.99
#
#                 instrument_name instrument_model  paired_read  \
# irods_filename
# 12135_1#31.cram            HS16            HiSeq            1
# 12135_1#32.cram            HS16            HiSeq            1
# 12135_1#33.cram            HS16            HiSeq            1
# 12135_1#34.cram            HS16            HiSeq            1
# 12135_1#35.cram            HS16            HiSeq            1
# 12135_1#36.cram            HS16            HiSeq            1
# 12135_2#37.cram            HS16            HiSeq            1
# 12135_2#38.cram            HS16            HiSeq            1
# 12135_2#39.cram            HS16            HiSeq            1
# 12135_2#40.cram            HS16            HiSeq            1
# 12135_2#41.cram            HS16            HiSeq            1
# 12135_2#42.cram            HS16            HiSeq            1
# 12135_3#43.cram            HS16            HiSeq            1
# 12135_3#44.cram            HS16            HiSeq            1
# 12135_3#45.cram            HS16            HiSeq            1
# 12135_3#46.cram            HS16            HiSeq            1
# 12135_3#47.cram            HS16            HiSeq            1
# 12135_3#48.cram            HS16            HiSeq            1
# 12135_4#49.cram            HS16            HiSeq            1
# 12135_4#50.cram            HS16            HiSeq            1
# 12135_4#51.cram            HS16            HiSeq            1
# 12135_4#52.cram            HS16            HiSeq            1
# 12135_4#53.cram            HS16            HiSeq            1
# 12135_4#54.cram            HS16            HiSeq            1
# 12135_5#55.cram            HS16            HiSeq            1
# 12135_5#56.cram            HS16            HiSeq            1
# 12135_5#57.cram            HS16            HiSeq            1
# 12135_5#58.cram            HS16            HiSeq            1
# 12135_5#59.cram            HS16            HiSeq            1
# 12135_5#60.cram            HS16            HiSeq            1
# 12135_6#61.cram            HS16            HiSeq            1
# 12135_6#62.cram            HS16            HiSeq            1
# 12135_6#63.cram            HS16            HiSeq            1
# 12135_6#64.cram            HS16            HiSeq            1
# 12135_6#65.cram            HS16            HiSeq            1
# 12135_6#66.cram            HS16            HiSeq            1
# 12135_7#67.cram            HS16            HiSeq            1
# 12135_7#68.cram            HS16            HiSeq            1
# 12135_7#70.cram 2014-02-28 12:53:57          1                       200.0
# 12135_7#71.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#73.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#74.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#75.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#76.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#77.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#78.cram 2014-02-28 12:53:57          1                       200.0
# 12135_8#79.cram 2014-02-28 12:53:57          1                       200.0
#
#                  requested_insert_size_to  forward_read_length  description
# irods_filename
# 12135_1#31.cram                     300.0                  100  qc complete
# 12135_1#32.cram                     300.0                  100  qc complete
# 12135_1#33.cram                     300.0                  100  qc complete
# 12135_1#34.cram                     300.0                  100  qc complete
# 12135_1#35.cram                     300.0                  100  qc complete
# 12135_1#36.cram                     300.0                  100  qc complete
# 12135_2#37.cram                     300.0                  100  qc complete
# 12135_2#38.cram                     300.0                  100  qc complete
# 12135_2#39.cram                     300.0                  100  qc complete
# 12135_2#40.cram                     300.0                  100  qc complete
# 12135_2#41.cram                     300.0                  100  qc complete
# 12135_2#42.cram                     300.0                  100  qc complete
# 12135_3#43.cram                     300.0                  100  qc complete
# 12135_3#44.cram                     300.0                  100  qc complete
# 12135_3#45.cram                     300.0                  100  qc complete
# 12135_3#46.cram                     300.0                  100  qc complete
# 12135_3#47.cram                     300.0                  100  qc complete
# 12135_3#48.cram                     300.0                  100  qc complete
# 12135_4#49.cram                     300.0                  100  qc complete
# 12135_4#50.cram                     300.0                  100  qc complete
# 12135_4#51.cram                     300.0                  100  qc complete
# 12135_4#52.cram                     300.0                  100  qc complete
# 12135_4#53.cram                     300.0                  100  qc complete
# 12135_4#54.cram                     300.0                  100  qc complete
# 12135_5#55.cram                     300.0                  100  qc complete
# 12135_5#56.cram                     300.0                  100  qc complete
# 12135_5#57.cram                     300.0                  100  qc complete
# 12135_5#58.cram                     300.0                  100  qc complete
# 12135_5#59.cram                     300.0                  100  qc complete
# 12135_5#60.cram                     300.0                  100  qc complete
# 12135_6#61.cram                     300.0                  100  qc complete
# 12135_6#62.cram                     300.0                  100  qc complete
# 12135_6#63.cram                     300.0                  100  qc complete
# 12135_6#64.cram                     300.0                  100  qc complete
# 12135_6#65.cram                     300.0                  100  qc complete
# 12135_6#66.cram                     300.0                  100  qc complete
# 12135_7#67.cram                     300.0                  100  qc complete
# 12135_7#68.cram                     300.0                  100  qc complete
# 12135_7#69.cram                     300.0                  100  qc complete
# 12135_7#70.cram                     300.0                  100  qc complete
# 12135_7#71.cram                     300.0                  100  qc complete
# 12135_8#73.cram                     300.0                  100  qc complete
# 12135_8#74.cram                     300.0                  100  qc complete
# 12135_8#75.cram                     300.0                  100  qc complete
# 12135_8#76.cram                     300.0                  100  qc complete
# 12135_8#77.cram                     300.0                  100  qc complete
# 12135_8#78.cram                     300.0                  100  qc complete
# 12135_8#79.cram                     300.0                  100  qc complete

# %%
'12135_6#65.cram' in df_mlwh.index
# Out:
# True

# %%
'12135_6#66.cram' in df_mlwh.index
# Out:
# True

# %% [markdown]
# # Add some constraints

# %%
def set_irods_name(row):
    # First calculate prefix using nonhuman dependent on id_run and species (taxon)
    # Then calculate tag string (empty string if no tag)
    # Then calculate file extension
    # Then concat these three strings
    if (
        (row['taxon_id'] in [7165, 7173, 30066, 62324]) & # Anopheles gambiae, arabiensis, merus and funestus respectively
        (row['id_run'] <= 6750)
    ):
        prefix = "%d_%d_nonhuman" % (row['id_run'], row['position'])
    elif (
        ~(row['taxon_id'] in [7165, 7173, 30066, 62324]) & # Anopheles gambiae, arabiensis, merus and funestus respectively
        (row['id_run'] <= 7100)
    ):
        prefix = "%d_%d_nonhuman" % (row['id_run'], row['position'])
    else:
        prefix = "%d_%d" % (row['id_run'], row['position'])
        
    if np.isnan(row['tag_index']):
        tag_string = ''
    else:
        tag_string = '#%d' % row['tag_index']
    
    if row['id_run'] <= 10300:
        file_extension = '.bam'
    else:
        file_extension = '.cram'
    
    irods_filename = prefix + tag_string + file_extension
    return(irods_filename)

def set_sample_id(row):
    if row['sample'] is None:
        return('DS_%s' % row['name'])
    else:
        return('DS_%s' % row['sample'])

def is_valid_alfresco_code(s):
    try: 
        int(s[0:4])
        return True
    except ValueError:
        return False

def create_build_manifest(
#     taxon_ids=[5833, 5855, 5858, 5821, 7165, 7173, 30066], # Pf, Pv, Pm, Pb, Ag, A. arabiensis, A. merus
    taxon_ids=[5833, 36329, 5847, 57267, 137071], # Pf, 3D7, V1, Dd2, HB3
    # 1089 is excluded as this is R&D samples. 1204 and 1176 are excluded as these are CP1 samples. 1175 is excluded as some Pf R&D samples were incorrectly tagged with this study
    studies_to_exclude = ['1089-R&amp;D-GB-ALCOCK', '1204-PF-GM-CP1', '1176-PF-KE-CP1', '1175-VO-KH-STLAURENT'],
    miseq_runs_to_allow = [13809, 13810], # Two Miseq runs within 24 samples on each from study 1095-PF-TZ-ISHENGOMA that were included in Pf 6.0
    input_dir = input_dir,
    mlwh_missing_exceptions_fn = mlwh_missing_exceptions_fn,
    mlwh_study_exceptions_fn = mlwh_study_exceptions_fn,
    mlwh_sample_exceptions_fn = mlwh_sample_exceptions_fn,
    mlwh_taxon_exceptions_fn = mlwh_taxon_exceptions_fn,
    sequencescape_alfresco_study_mappings_fn = sequencescape_alfresco_study_mappings_fn,
    output_columns = [
        'path',
        'study',
        'sample',
        'lane',
        'reads',
        'paired',
        'irods_path',
        'sanger_sample_id',
        'taxon_id',
        'study_lims',
        'study_name',
        'id_run',
        'position',
        'tag_index',
        'qc_complete',
        'manual_qc',
        'description',
        'instrument_name',
        'instrument_model',
        'forward_read_length',
        'requested_insert_size_from',
        'requested_insert_size_to',
        'human_percent_mapped',
        'subtrack_filename',
        'subtrack_files_bytes',
        'ebi_run_acc'
    ]
):
    """Create a DataFrame to be used as a build manifest.
    
    A build manifest here is a list of all the "lanelets" that need to be
    included in a build. The output will typically be written to a
    tab-delmited file, either to use as input to vr-pipe, or perhaps as
    input to a vr-track DB.

    Args:
        taxon_ids (list of int): The taxons of the build (P. falciparum is '5833',
            P. vivax is '5855').
        sequencescape_alfresco_study_mappings_fn (str): filename of
            mappings from sequencscape to alfresco study mappings

    Returns:
        pd.DataFrame: The build manifest.

    """
    
    # Read in taxon exceptions file
    df_mlwh_taxon_exceptions = pd.read_csv(mlwh_taxon_exceptions_fn, sep='\t', dtype={'tag_index': str, 'taxon_id': int}, index_col='irods_filename')
    df_mlwh_taxon_exceptions['tag_index'].fillna('', inplace=True)
    # Identify which samples in exceptions file match the taxon of current build, and which don't
    df_mlwh_exceptions_this_taxon = df_mlwh_taxon_exceptions.loc[df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids)]
    df_mlwh_exceptions_other_taxa = df_mlwh_taxon_exceptions.loc[~(df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids))]

    # Read in sample exceptions file
    df_mlwh_sample_exceptions = pd.read_csv(mlwh_sample_exceptions_fn, sep='\t', index_col='irods_filename')

    # Read in study exceptions file
    df_mlwh_study_exceptions = pd.read_csv(mlwh_study_exceptions_fn, sep='\t', index_col='irods_filename')

    # Read in missing exceptions file
    df_mlwh_missing_exceptions = pd.read_csv(mlwh_missing_exceptions_fn, sep='\t', index_col='irods_filename')
    df_mlwh_missing_exceptions['derivative_sample_id'] = 'DS_' + df_mlwh_missing_exceptions['sample_id']
    df_mlwh_missing_exceptions = df_mlwh_missing_exceptions.loc[
        df_mlwh_missing_exceptions['taxon_id'].isin(taxon_ids)
    ]

    # Read in SequenceScape-Alfresco study mappings
    df_sequencescape_alfresco_study_mappings = pd.read_csv(sequencescape_alfresco_study_mappings_fn, sep='\t', index_col='seqscape_study_id')
    sequencescape_alfresco_study_mappings_dict = df_sequencescape_alfresco_study_mappings.loc[
        :,
#         df_sequencescape_alfresco_study_mappings['build_flag']==1,
        'alfresco_study_code'
    ].to_dict()
    
    # Read in data from mlwh matching this taxon, plus samples from exceptions file matching this taxon
    conn = pymysql.connect(
        host='mlwh-db',
        user='mlwh_malaria',
        password='Solaris&2015',
        db='mlwarehouse',
        port=3435
    )
    
    sql_query = 'SELECT \
        study.name as study_name, \
        study.id_study_lims as study_lims, \
        sample.supplier_name as sample, \
        sample.name, \
        sample.sanger_sample_id, \
        sample.taxon_id, \
        iseq_product_metrics.id_run, \
        iseq_product_metrics.position, \
        iseq_product_metrics.tag_index, \
        iseq_product_metrics.num_reads, \
        iseq_product_metrics.human_percent_mapped, \
        iseq_run_lane_metrics.instrument_name, \
        iseq_run_lane_metrics.instrument_model, \
        iseq_run_lane_metrics.paired_read, \
        iseq_run_lane_metrics.qc_complete, \
        iseq_flowcell.manual_qc, \
        iseq_flowcell.requested_insert_size_from, \
        iseq_flowcell.requested_insert_size_to, \
        iseq_flowcell.forward_read_length, \
        iseq_run_status_dict.description \
    FROM \
        study, \
        iseq_flowcell, \
        sample, \
        iseq_product_metrics, \
        iseq_run_status, \
        iseq_run_lane_metrics, \
        iseq_run_status_dict \
    WHERE \
        study.id_study_tmp = iseq_flowcell.id_study_tmp and \
        iseq_flowcell.id_sample_tmp = sample.id_sample_tmp and \
        iseq_flowcell.manual_qc = 1 and \
        iseq_product_metrics.id_iseq_flowcell_tmp = iseq_flowcell.id_iseq_flowcell_tmp and \
        iseq_run_status.id_run = iseq_product_metrics.id_run and \
        iseq_product_metrics.id_run = iseq_run_lane_metrics.id_run and \
        iseq_product_metrics.position = iseq_run_lane_metrics.position and \
        iseq_run_status.iscurrent = 1 and \
        ( ( iseq_run_lane_metrics.instrument_model != "MiSeq" ) or (iseq_product_metrics.id_run in (%s)) ) and \
        iseq_run_status.id_run_status_dict = iseq_run_status_dict.id_run_status_dict and \
        study.faculty_sponsor = "Dominic Kwiatkowski" and \
        ( ( sample.taxon_id in (%s) ) or ' % (
            ', '.join([str(x) for x in miseq_runs_to_allow]),
            ', '.join([str(x) for x in taxon_ids])
        )
    sql_query = sql_query + ' or '.join(
        df_mlwh_taxon_exceptions.loc[df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids)].apply(
            lambda x: '(iseq_product_metrics.id_run="%s" and iseq_product_metrics.position="%s" and iseq_product_metrics.tag_index="%s")' % (x['id_run'], x['position'], x['tag_index']),
            1
        )
    )
    sql_query = sql_query + ')'
#         (iseq_flowcell.manual_qc = 1 or iseq_flowcell.manual_qc is null) and \
    
    df_return = pd.read_sql(sql_query, conn)

    # Replace missing taxon_id with -1 (can't have missing int values in pandas Series)
    df_return['taxon_id'] = df_return['taxon_id'].fillna(-1).astype('int32')

    # Determine file name in iRods
    df_return['irods_filename'] = df_return.apply(set_irods_name, 1)
    df_return.set_index('irods_filename', inplace=True)

    # Determine alfresco study and change any incorrect studies
    df_return['alfresco_study_code'] = df_return['study_lims'].apply(
        lambda x: sequencescape_alfresco_study_mappings_dict[int(x)] if int(x) in sequencescape_alfresco_study_mappings_dict else ''
    )
    empty_alfresco_study_code = (df_return['alfresco_study_code'] == '')
    df_return.loc[empty_alfresco_study_code, 'alfresco_study_code'] = df_return.loc[empty_alfresco_study_code, 'study_name']
    
    study_exception_indexes = df_mlwh_study_exceptions.index[
        df_mlwh_study_exceptions.index.isin(df_return.index)
    ]
    df_return.loc[study_exception_indexes, 'alfresco_study_code'] = df_mlwh_study_exceptions.loc[study_exception_indexes, 'alfresco_study_code']

    # Change any incorrect taxon IDs
    taxon_exception_indexes = df_mlwh_exceptions_this_taxon.index[
        df_mlwh_exceptions_this_taxon.index.to_series().isin(df_return.index)
    ]
    df_return.loc[taxon_exception_indexes, 'taxon_id'] = df_mlwh_exceptions_this_taxon.loc[taxon_exception_indexes, 'taxon_id']

    # Determine sample ID and change any incorrect sample IDs
    df_return['derivative_sample_id'] = df_return.apply(set_sample_id, 1)
    sample_exception_indexes = df_mlwh_sample_exceptions.index[
        df_mlwh_sample_exceptions.index.isin(df_return.index)
    ]    
    df_return.loc[sample_exception_indexes, 'derivative_sample_id'] = 'DS_' + df_mlwh_sample_exceptions.loc[sample_exception_indexes, 'sample_id']
    df_return.drop(['sample', 'name'], axis=1, inplace=True)
    
    # Remove any samples that are not in this taxon
    df_return = df_return.loc[~df_return.index.isin(df_mlwh_exceptions_other_taxa.index)]

    return(df_return)

# %%
df_mlwh_taxa_exceptions = create_build_manifest()
print(df_mlwh_taxa_exceptions.shape)
print('6901_8_nonhuman#1.bam' in df_mlwh_taxa_exceptions.index)
print('6901_8_nonhuman#2.bam' in df_mlwh_taxa_exceptions.index)
print('12135_6#65.cram' in df_mlwh_taxa_exceptions.index)
print('12135_6#66.cram' in df_mlwh_taxa_exceptions.index)
# Out:
# (23430, 20)
# True
# True
# True
# True

# %%
df_mlwh_taxa_exceptions.loc[['6901_8_nonhuman#1.bam', '6901_8_nonhuman#2.bam']]
# Out:
#                                                      study_name study_lims  \
# irods_filename
# 6901_8_nonhuman#1.bam  Plasmodium falciparum genome variation 1        578
# 6901_8_nonhuman#2.bam  Plasmodium falciparum genome variation 1        578
#
#                       sanger_sample_id  taxon_id  id_run  position  tag_index  \
# irods_filename
# 6901_8_nonhuman#1.bam             None      5833    6901         8        1.0
# 6901_8_nonhuman#2.bam             None      5833    6901         8        2.0
#
#                        num_reads  human_percent_mapped instrument_name  \
# irods_filename
# 6901_8_nonhuman#1.bam    4969844                 99.42            HS13
# 6901_8_nonhuman#2.bam      52856                 93.42            HS13
#
#                       instrument_model  paired_read         qc_complete  \
# irods_filename
# 6901_8_nonhuman#1.bam            HiSeq            1 2011-11-01 12:52:25
# 6901_8_nonhuman#2.bam            HiSeq            1 2011-11-01 12:52:25
#
#                        manual_qc  requested_insert_size_from  \
# irods_filename
# 6901_8_nonhuman#1.bam          1                       200.0
# 6901_8_nonhuman#2.bam          1                       200.0
#
#                        requested_insert_size_to  forward_read_length  \
# irods_filename
# 6901_8_nonhuman#1.bam                     300.0                  100
# 6901_8_nonhuman#2.bam                     300.0                  100
#
#                        description                       alfresco_study_code  \
# irods_filename
# 6901_8_nonhuman#1.bam  qc complete                        1052-PF-TRAC-WHITE
# 6901_8_nonhuman#2.bam  qc complete  Plasmodium falciparum genome variation 1
#
#                       derivative_sample_id
# irods_filename
# 6901_8_nonhuman#1.bam          DS_PH0540-C
# 6901_8_nonhuman#2.bam              DS_Tr5E

# %% [markdown]
# ### Summary
# Missing files still included here - add more constraints...

# %%
def create_build_manifest(
#     taxon_ids=[5833, 5855, 5858, 5821, 7165, 7173, 30066], # Pf, Pv, Pm, Pb, Ag, A. arabiensis, A. merus
    taxon_ids=[5833, 36329, 5847, 57267, 137071], # Pf, 3D7, V1, Dd2, HB3
    # 1089 is excluded as this is R&D samples. 1204 and 1176 are excluded as these are CP1 samples. 1175 is excluded as some Pf R&D samples were incorrectly tagged with this study
    studies_to_exclude = ['1089-R&amp;D-GB-ALCOCK', '1204-PF-GM-CP1', '1176-PF-KE-CP1', '1175-VO-KH-STLAURENT'],
    miseq_runs_to_allow = [13809, 13810], # Two Miseq runs within 24 samples on each from study 1095-PF-TZ-ISHENGOMA that were included in Pf 6.0
    input_dir = input_dir,
    mlwh_missing_exceptions_fn = mlwh_missing_exceptions_fn,
    mlwh_study_exceptions_fn = mlwh_study_exceptions_fn,
    mlwh_sample_exceptions_fn = mlwh_sample_exceptions_fn,
    mlwh_taxon_exceptions_fn = mlwh_taxon_exceptions_fn,
    sequencescape_alfresco_study_mappings_fn = sequencescape_alfresco_study_mappings_fn,
    output_columns = [
        'path',
        'study',
        'sample',
        'lane',
        'reads',
        'paired',
        'irods_path',
        'sanger_sample_id',
        'taxon_id',
        'study_lims',
        'study_name',
        'id_run',
        'position',
        'tag_index',
        'qc_complete',
        'manual_qc',
        'description',
        'instrument_name',
        'instrument_model',
        'forward_read_length',
        'requested_insert_size_from',
        'requested_insert_size_to',
        'human_percent_mapped',
        'subtrack_filename',
        'subtrack_files_bytes',
        'ebi_run_acc'
    ]
):
    """Create a DataFrame to be used as a build manifest.
    
    A build manifest here is a list of all the "lanelets" that need to be
    included in a build. The output will typically be written to a
    tab-delmited file, either to use as input to vr-pipe, or perhaps as
    input to a vr-track DB.

    Args:
        taxon_ids (list of int): The taxons of the build (P. falciparum is '5833',
            P. vivax is '5855').
        sequencescape_alfresco_study_mappings_fn (str): filename of
            mappings from sequencscape to alfresco study mappings

    Returns:
        pd.DataFrame: The build manifest.

    """
    
    # Read in taxon exceptions file
    df_mlwh_taxon_exceptions = pd.read_csv(mlwh_taxon_exceptions_fn, sep='\t', dtype={'tag_index': str, 'taxon_id': int}, index_col='irods_filename')
    df_mlwh_taxon_exceptions['tag_index'].fillna('', inplace=True)
    # Identify which samples in exceptions file match the taxon of current build, and which don't
    df_mlwh_exceptions_this_taxon = df_mlwh_taxon_exceptions.loc[df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids)]
    df_mlwh_exceptions_other_taxa = df_mlwh_taxon_exceptions.loc[~(df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids))]

    # Read in sample exceptions file
    df_mlwh_sample_exceptions = pd.read_csv(mlwh_sample_exceptions_fn, sep='\t', index_col='irods_filename')

    # Read in study exceptions file
    df_mlwh_study_exceptions = pd.read_csv(mlwh_study_exceptions_fn, sep='\t', index_col='irods_filename')

    # Read in missing exceptions file
    df_mlwh_missing_exceptions = pd.read_csv(mlwh_missing_exceptions_fn, sep='\t', index_col='irods_filename')
    df_mlwh_missing_exceptions['derivative_sample_id'] = 'DS_' + df_mlwh_missing_exceptions['sample_id']
    df_mlwh_missing_exceptions = df_mlwh_missing_exceptions.loc[
        df_mlwh_missing_exceptions['taxon_id'].isin(taxon_ids)
    ]

    # Read in SequenceScape-Alfresco study mappings
    df_sequencescape_alfresco_study_mappings = pd.read_csv(sequencescape_alfresco_study_mappings_fn, sep='\t', index_col='seqscape_study_id')
    sequencescape_alfresco_study_mappings_dict = df_sequencescape_alfresco_study_mappings.loc[
        :,
#         df_sequencescape_alfresco_study_mappings['build_flag']==1,
        'alfresco_study_code'
    ].to_dict()
    
    # Read in data from mlwh matching this taxon, plus samples from exceptions file matching this taxon
    conn = pymysql.connect(
        host='mlwh-db',
        user='mlwh_malaria',
        password='Solaris&2015',
        db='mlwarehouse',
        port=3435
    )
    
    sql_query = 'SELECT \
        study.name as study_name, \
        study.id_study_lims as study_lims, \
        sample.supplier_name as sample, \
        sample.name, \
        sample.sanger_sample_id, \
        sample.taxon_id, \
        iseq_product_metrics.id_run, \
        iseq_product_metrics.position, \
        iseq_product_metrics.tag_index, \
        iseq_product_metrics.num_reads, \
        iseq_product_metrics.human_percent_mapped, \
        iseq_run_lane_metrics.instrument_name, \
        iseq_run_lane_metrics.instrument_model, \
        iseq_run_lane_metrics.paired_read, \
        iseq_run_lane_metrics.qc_complete, \
        iseq_flowcell.manual_qc, \
        iseq_flowcell.requested_insert_size_from, \
        iseq_flowcell.requested_insert_size_to, \
        iseq_flowcell.forward_read_length, \
        iseq_run_status_dict.description \
    FROM \
        study, \
        iseq_flowcell, \
        sample, \
        iseq_product_metrics, \
        iseq_run_status, \
        iseq_run_lane_metrics, \
        iseq_run_status_dict \
    WHERE \
        study.id_study_tmp = iseq_flowcell.id_study_tmp and \
        iseq_flowcell.id_sample_tmp = sample.id_sample_tmp and \
        iseq_flowcell.manual_qc = 1 and \
        iseq_product_metrics.id_iseq_flowcell_tmp = iseq_flowcell.id_iseq_flowcell_tmp and \
        iseq_run_status.id_run = iseq_product_metrics.id_run and \
        iseq_product_metrics.id_run = iseq_run_lane_metrics.id_run and \
        iseq_product_metrics.position = iseq_run_lane_metrics.position and \
        iseq_run_status.iscurrent = 1 and \
        ( ( iseq_run_lane_metrics.instrument_model != "MiSeq" ) or (iseq_product_metrics.id_run in (%s)) ) and \
        iseq_run_status.id_run_status_dict = iseq_run_status_dict.id_run_status_dict and \
        study.faculty_sponsor = "Dominic Kwiatkowski" and \
        ( ( sample.taxon_id in (%s) ) or ' % (
            ', '.join([str(x) for x in miseq_runs_to_allow]),
            ', '.join([str(x) for x in taxon_ids])
        )
    sql_query = sql_query + ' or '.join(
        df_mlwh_taxon_exceptions.loc[df_mlwh_taxon_exceptions['taxon_id'].isin(taxon_ids)].apply(
            lambda x: '(iseq_product_metrics.id_run="%s" and iseq_product_metrics.position="%s" and iseq_product_metrics.tag_index="%s")' % (x['id_run'], x['position'], x['tag_index']),
            1
        )
    )
    sql_query = sql_query + ')'
#         (iseq_flowcell.manual_qc = 1 or iseq_flowcell.manual_qc is null) and \
    
    df_return = pd.read_sql(sql_query, conn)

    # Replace missing taxon_id with -1 (can't have missing int values in pandas Series)
    df_return['taxon_id'] = df_return['taxon_id'].fillna(-1).astype('int32')

    # Determine file name in iRods
    df_return['irods_filename'] = df_return.apply(set_irods_name, 1)
    df_return.set_index('irods_filename', inplace=True)

    # Determine alfresco study and change any incorrect studies
    df_return['alfresco_study_code'] = df_return['study_lims'].apply(
        lambda x: sequencescape_alfresco_study_mappings_dict[int(x)] if int(x) in sequencescape_alfresco_study_mappings_dict else ''
    )
    empty_alfresco_study_code = (df_return['alfresco_study_code'] == '')
    df_return.loc[empty_alfresco_study_code, 'alfresco_study_code'] = df_return.loc[empty_alfresco_study_code, 'study_name']
    
    study_exception_indexes = df_mlwh_study_exceptions.index[
        df_mlwh_study_exceptions.index.isin(df_return.index)
    ]
    df_return.loc[study_exception_indexes, 'alfresco_study_code'] = df_mlwh_study_exceptions.loc[study_exception_indexes, 'alfresco_study_code']

    # Change any incorrect taxon IDs
    taxon_exception_indexes = df_mlwh_exceptions_this_taxon.index[
        df_mlwh_exceptions_this_taxon.index.to_series().isin(df_return.index)
    ]
    df_return.loc[taxon_exception_indexes, 'taxon_id'] = df_mlwh_exceptions_this_taxon.loc[taxon_exception_indexes, 'taxon_id']

    # Determine sample ID and change any incorrect sample IDs
    df_return['derivative_sample_id'] = df_return.apply(set_sample_id, 1)
    sample_exception_indexes = df_mlwh_sample_exceptions.index[
        df_mlwh_sample_exceptions.index.isin(df_return.index)
    ]    
    df_return.loc[sample_exception_indexes, 'derivative_sample_id'] = 'DS_' + df_mlwh_sample_exceptions.loc[sample_exception_indexes, 'sample_id']
    df_return.drop(['sample', 'name'], axis=1, inplace=True)
    
    # Remove any samples that are not in this taxon
    df_return = df_return.loc[~df_return.index.isin(df_mlwh_exceptions_other_taxa.index)]

    # Merge in missing exceptions
    df_return = df_return.append(df_mlwh_missing_exceptions.drop('study_group', 1))
    
    # Remove any samples that don't have an alfresco study
    invalid_codes = ~df_return['alfresco_study_code'].apply(is_valid_alfresco_code)
    if(np.count_nonzero(invalid_codes) > 0):
        print('Removing %d files with invalid alfresco_study_code:' % np.count_nonzero(invalid_codes))
        print(df_return['alfresco_study_code'].loc[invalid_codes].value_counts())
        df_return = df_return.loc[~invalid_codes]

    return(df_return)

# %%
df_mlwh_pre_subtrack = create_build_manifest()
print(df_mlwh_pre_subtrack.shape)
print('6901_8_nonhuman#1.bam' in df_mlwh_pre_subtrack.index)
print('6901_8_nonhuman#2.bam' in df_mlwh_pre_subtrack.index)
print('12135_6#65.cram' in df_mlwh_pre_subtrack.index)
print('12135_6#66.cram' in df_mlwh_pre_subtrack.index)
# Out:
# Removing 63 files with invalid alfresco_study_code:
# AT-rich amplification                                 53
# Test sequencing of high level human contamination.     6
# Plasmodium falciparum genome variation 1               4
# Name: alfresco_study_code, dtype: int64
# (23773, 21)
# True
# False
# True
# False

# %%
df_mlwh_taxa_exceptions.loc[['6901_8_nonhuman#1.bam', '6901_8_nonhuman#2.bam', '12135_6#65.cram', '12135_6#66.cram'], 'alfresco_study_code']
# Out:
# irods_filename
# 6901_8_nonhuman#1.bam                                   1052-PF-TRAC-WHITE
# 6901_8_nonhuman#2.bam             Plasmodium falciparum genome variation 1
# 12135_6#65.cram                                       1044-PF-KH-FAIRHURST
# 12135_6#66.cram          Test sequencing of high level human contaminat...
# Name: alfresco_study_code, dtype: object

# %% [markdown]
# # Conclusion
# The missing files were in sequencescape studies that don't have a direct mapping to Alfresco studies. As such we can only attach an Alfresco study if the file was in vw_vrpipe, but these 10 files weren't in vw_vrpipe. My script removes any sample without a valid Alfresco study, and hence these got removed.
#
# Would recommend adding these as manifest exceptions with the explanation "In sequencescape study without corresponding Alfresco study and not in vw_vrpipe".
